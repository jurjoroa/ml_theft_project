# %% [markdown]
# This script is intended to clean the data of the Mexican social indicators.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np



# %cd 'Documents/GitHub/pmx_gasoline_theft_prediction/'
# Out:
# /Users/jorgeroa/Documents/GitHub/pmx_gasoline_theft_prediction

# %%
df_social_2015_ori = pd.read_excel("data-raw/IRS_2015.xlsx")
df_social_2020_ori = pd.read_excel("data-raw/IRS_2020.xlsx")

# %%
df_social_2015_ori
# Out:
#       CVEGEO  POB_TOT   SBASC  POB_6_16_NEB  POB_16_EBI    NO_SS    OVPT  \
# 0       1001   877190  2.0570        3.4786     25.6873  14.1560  0.5478
# 1       1002    46464  4.4207        2.5959     41.8921   5.5355  1.6779
# 2       1003    56048  4.7805        4.3906     49.1856   9.7524  1.0577
# 3       1004    15577  4.3233        2.6265     33.0597   5.1165  1.5629
# 4       1005   120405  3.2445        4.1297     33.7271  13.8341  0.9201
# ...      ...      ...     ...           ...         ...      ...     ...
# 2441   32054    19155  8.1332        3.6565     42.1699   8.8384  2.5438
# 2442   32055    30240  4.7985        3.4198     53.7212  13.5516  0.9201
# 2443   32056   146147  1.2432        2.1746     23.0304  14.0968  0.2485
# 2444   32057    19413  5.6122        2.5997     42.0488   9.0609  1.1950
# 2445   32058     2656  5.3388        1.2563     50.6674  20.5196  3.9949
#
#       NO_SANIT   OVSAE  NO_DREN  NO_ELECT  NO_LAVA  No_REFRI       IRS  \
# 0       0.5543  0.6627   0.4819    0.1999  13.8229    5.4216 -1.365841
# 1       5.6457  1.2979   5.9887    1.1681  23.4356   15.2220 -0.883915
# 2       0.7756  0.9519   0.8673    0.5429  15.5620    7.3826 -0.979457
# 3       2.8986  0.5968   1.9324    0.7389  23.0747   12.4467 -1.062688
# 4       1.0273  0.9443   0.7264    0.4220  15.5097    8.1976 -1.188620
# ...        ...     ...      ...       ...      ...       ...       ...
# 2441    8.9568  3.8478  11.2869    1.5391  26.3574   24.1770 -0.597363
# 2442    4.8484  1.7459   6.0871    0.9673  15.5715    6.0517 -0.903369
# 2443    1.2004  1.6826   0.9519    0.1640  11.8377    5.5249 -1.446286
# 2444    6.9448  3.0891   5.6595    1.1499  24.4419   22.0744 -0.801200
# 2445    4.3814  1.2887  12.7577    0.1289  27.1907   15.8505 -0.788234
#
#          grade  place
# 0     Muy bajo   2397
# 1         Bajo   1950
# 2         Bajo   2077
# 3     Muy bajo   2164
# 4     Muy bajo   2286
# ...        ...    ...
# 2441      Bajo   1640
# 2442      Bajo   1976
# 2443  Muy bajo   2423
# 2444      Bajo   1873
# 2445      Bajo   1855
#
# [2446 rows x 16 columns]

# %%
df_social_2020_ori
# Out:
#       CVEGEO  POB_TOT     SBASC  POB_6_16_NEB  POB_16_EBI      NO_SS  \
# 0       1001   948990  1.642183      4.601069   20.252928  18.250877
# 1       1002    51536  3.523404      6.294853   33.869504  14.727569
# 2       1003    58250  4.487288      6.948460   42.424388  20.312446
# 3       1004    17000  3.139545      5.697637   27.595837  13.805882
# 4       1005   129929  2.377387      5.877568   26.604873  21.010706
# ...      ...      ...       ...           ...         ...        ...
# 2464   32054    19446  7.489290      4.534543   36.604957  15.473619
# 2465   32055    31558  4.196878      5.288837   44.877591  25.163192
# 2466   32056   149607  1.437077      3.669372   19.253869  16.944394
# 2467   32057    20455  5.116885      5.658915   31.989578  13.840137
# 2468   32058     2767  5.609756      5.152225   44.048780  14.853632
#
#           OVPT  NO_SANIT     OVSAE   NO_DREN  NO_ELECT    NO_LAVA   No_REFRI  \
# 0     0.574092  0.272787  0.371096  0.299428  0.164348  12.125340   4.333453
# 1     1.469414  3.825268  0.990257  3.569717  0.758665  17.696854  11.587606
# 2     1.121134  0.715206  0.940722  0.663660  0.721649  12.628866   5.547680
# 3     1.017553  2.009667  0.788603  1.195625  0.635970  18.519461  10.506233
# 4     1.239034  0.584848  0.862199  0.780803  0.467276  12.007476   5.296795
# ...        ...       ...       ...       ...       ...        ...        ...
# 2464  1.414141  4.161616  2.040404  5.919192  0.666667  19.656566  15.878788
# 2465  1.073959  3.011515  1.262179  3.974756  0.830381  11.625332   5.580159
# 2466  0.479090  0.535731  1.106863  0.429529  0.181724  10.738223   4.559615
# 2467  1.392459  4.584404  3.191945  4.284490  0.578406  20.651243  17.245073
# 2468  2.564103  1.981352  0.815851  4.545455  0.932401  17.832168   9.673660
#
#            IRS     grade  place
# 0    -1.315320  Muy bajo   2435
# 1    -0.857301  Muy bajo   1986
# 2    -0.918554  Muy bajo   2076
# 3    -1.004023  Muy bajo   2178
# 4    -1.173361  Muy bajo   2347
# ...        ...       ...    ...
# 2464 -0.692240      Bajo   1768
# 2465 -0.884952  Muy bajo   2020
# 2466 -1.336926  Muy bajo   2444
# 2467 -0.748505  Muy bajo   1841
# 2468 -0.729746  Muy bajo   1815
#
# [2469 rows x 16 columns]

# %%
#create a new dataframe, rename and drop some variables - 2015

df_social_2015 = df_social_2015_ori.rename(columns = {'CVEGEO' : 'Mun_Code'})
df_social_2015.drop(['POB_TOT', 'place'], axis = 1, inplace = True)
df_social_2015['Mun_Code'] = df_social_2015['Mun_Code'].astype(str).str.zfill(5)

print(df_social_2015.head())

#create a new dataframe, rename and drop some variables - 2015

df_social_2020 = df_social_2020_ori.rename(columns = {'CVEGEO' : 'Mun_Code'})
df_social_2020.drop(['POB_TOT', 'place'], axis = 1, inplace = True)
df_social_2020['Mun_Code'] = df_social_2020['Mun_Code'].astype(str).str.zfill(5)


df_social_2020.head()
# Out:
#   Mun_Code   SBASC  POB_6_16_NEB  POB_16_EBI    NO_SS    OVPT  NO_SANIT  \
# 0    01001  2.0570        3.4786     25.6873  14.1560  0.5478    0.5543
# 1    01002  4.4207        2.5959     41.8921   5.5355  1.6779    5.6457
# 2    01003  4.7805        4.3906     49.1856   9.7524  1.0577    0.7756
# 3    01004  4.3233        2.6265     33.0597   5.1165  1.5629    2.8986
# 4    01005  3.2445        4.1297     33.7271  13.8341  0.9201    1.0273
#
#     OVSAE  NO_DREN  NO_ELECT  NO_LAVA  No_REFRI       IRS     grade
# 0  0.6627   0.4819    0.1999  13.8229    5.4216 -1.365841  Muy bajo
# 1  1.2979   5.9887    1.1681  23.4356   15.2220 -0.883915      Bajo
# 2  0.9519   0.8673    0.5429  15.5620    7.3826 -0.979457      Bajo
# 3  0.5968   1.9324    0.7389  23.0747   12.4467 -1.062688  Muy bajo
# 4  0.9443   0.7264    0.4220  15.5097    8.1976 -1.188620  Muy bajo
#   Mun_Code     SBASC  POB_6_16_NEB  POB_16_EBI      NO_SS      OVPT  NO_SANIT  \
# 0    01001  1.642183      4.601069   20.252928  18.250877  0.574092  0.272787
# 1    01002  3.523404      6.294853   33.869504  14.727569  1.469414  3.825268
# 2    01003  4.487288      6.948460   42.424388  20.312446  1.121134  0.715206
# 3    01004  3.139545      5.697637   27.595837  13.805882  1.017553  2.009667
# 4    01005  2.377387      5.877568   26.604873  21.010706  1.239034  0.584848
#
#       OVSAE   NO_DREN  NO_ELECT    NO_LAVA   No_REFRI       IRS     grade
# 0  0.371096  0.299428  0.164348  12.125340   4.333453 -1.315320  Muy bajo
# 1  0.990257  3.569717  0.758665  17.696854  11.587606 -0.857301  Muy bajo
# 2  0.940722  0.663660  0.721649  12.628866   5.547680 -0.918554  Muy bajo
# 3  0.788603  1.195625  0.635970  18.519461  10.506233 -1.004023  Muy bajo
# 4  0.862199  0.780803  0.467276  12.007476   5.296795 -1.173361  Muy bajo

# %%
# check if there is NAN or empty cells

#np.where(pd.isnull(df_social_2020))

#pd.isna(df_social_2020['ANALF'])
df_social_2020['ANALF'] == ''
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2464    False
# 2465    False
# 2466    False
# 2467    False
# 2468    False
# Name: ANALF, Length: 2469, dtype: bool

# %%
#Join Databases 2015 and 2020 - TEST THE IF CASE

# df_social_2015_2020_2 = df_social_2020.join(df_social_2015.set_index('Mun_Code'), lsuffix='_S2020', rsuffix='_S2015', on = 'Mun_Code', how = 'left')

# social_indicators = ['ANALF', 'SBASC', 'OVSDE', 'OVSEE', 'OVSAE', 'OVPT', 'VHAC', 'PL.5000', 'PO2SM', 'IMN']

# # Loop over the joined dataframe to calculate to value to 2019 and the mean between 2015-2019
# for key in social_indicators:
#   if df_social_2015_2020_2[key+'_S2015'].isnull() { 
#       df_social_2015_2020_2[key+'_var_Anual'] = df_social_2015_2020_2[key+'_S2020'] / 5
#       df_social_2015_2020_2[key+'_S2019'] = df_social_2015_2020_2[key+'_var_Anual'] * 4
#       df_social_2015_2020_2[key+'_mean_15_19'] = (df_social_2015_2020_2[key+'_S2019']) /2
     
#   } else {
#       df_social_2015_2020_2[key+'_var_Anual'] = (df_social_2015_2020_2[key+'_S2020'].div(df_social_2015_2020_2[key+'_S2015'].values))**(1/5)
#       df_social_2015_2020_2[key+'_S2019'] = (df_social_2015_2020_2[key+'_S2015'] * ((df_social_2015_2020_2[key+'_var_Anual'])**4))
#       df_social_2015_2020_2[key+'_mean_15_19'] = (df_social_2015_2020_2[key+'_S2015'] + df_social_2015_2020_2[key+'_S2019']) /2
#   }
 
# # Generate a mean dataframe and rename the variables
# df_social_mean_2015_2019_2 = df_social_2015_2020_2[df_social_2015_2020_2.columns[df_social_2015_2020_2.columns.str.contains("_mean_15_19|Mun_Code")]]
# df_social_mean_2015_2019_2 = df_social_mean_2015_2019_2.rename(columns = {'ANALF_mean_15_19' : 'ANALF', 'SBASC_mean_15_19' : 'SBASC', 'OVSDE_mean_15_19' : 'OVSDE', 'OVSEE_mean_15_19' : 'OVSEE', 'OVSAE_mean_15_19' : 'OVSAE', 'OVPT_mean_15_19' : 'OVPT', 'VHAC_mean_15_19' : 'VHAC', 'PL.5000_mean_15_19' : 'PL.5000', 'PO2SM_mean_15_19' : 'PO2SM', 'IMN_mean_15_19' : 'IMN'})
# df_social_mean_2015_2019_2

# %%
#Join Databases 2015 and 2020

df_social_2015_2020 = df_social_2015.join(df_social_2020.set_index('Mun_Code'), lsuffix='_S2015', rsuffix='_S2020', on = 'Mun_Code', how = 'outer')

social_indicators = ["SBASC", "POB_6_16_NEB", "POB_16_EBI", "NO_SS", "OVPT", "NO_SANIT", "OVSAE", "NO_DREN", "NO_ELECT", "NO_LAVA", "No_REFRI", "IRS"]

# Loop over the joined dataframe to calculate to value to 2019 and the mean between 2015-2019
for key in social_indicators:
      df_social_2015_2020[key+'_var_Anual'] = (df_social_2015_2020[key+'_S2020'].div(df_social_2015_2020[key+'_S2015'].values))**(1/5)
      df_social_2015_2020[key+'_S2019'] = (df_social_2015_2020[key+'_S2015'] * ((df_social_2015_2020[key+'_var_Anual'])**4))
      df_social_2015_2020[key+'_mean_15_19'] = (df_social_2015_2020[key+'_S2015'] + df_social_2015_2020[key+'_S2019']) /2

# Generate a mean dataframe and rename the variables
df_social_mean_2015_2019 = df_social_2015_2020[df_social_2015_2020.columns[df_social_2015_2020.columns.str.contains("_mean_15_19|Mun_Code")]]

df_social_mean_2015_2019.columns = df_social_mean_2015_2019.columns.str.replace("_mean_15_19", "", regex=True)
#df_social_mean_2015_2019 = df_social_mean_2015_2019.rename(columns = {'ANALF_mean_15_19' : 'ANALF', 'SBASC_mean_15_19' : 'SBASC', 'OVSDE_mean_15_19' : 'OVSDE', 'OVSEE_mean_15_19' : 'OVSEE', 'OVSAE_mean_15_19' : 'OVSAE', 'OVPT_mean_15_19' : 'OVPT', 'VHAC_mean_15_19' : 'VHAC', 'PL.5000_mean_15_19' : 'PL.5000', 'PO2SM_mean_15_19' : 'PO2SM', 'IMN_mean_15_19' : 'IMN'})
df_social_mean_2015_2019
# Out:
#     Mun_Code     SBASC  POB_6_16_NEB  POB_16_EBI      NO_SS      OVPT  \
# 0.0    01001  1.887423      3.914694   23.463147  15.751315  0.558267
# 1.0    01002  4.053829      3.934379   38.616333   8.822640  1.593414
# 2.0    01003  4.662478      5.364763   46.441725  13.646250  1.082925
# 3.0    01004  3.835153      3.753315   30.835403   8.218243  1.335823
# 4.0    01005  2.887218      4.803344   30.812283  16.580066  1.043769
# ..       ...       ...           ...         ...        ...       ...
# NaN    20407       NaN           NaN         NaN        NaN       NaN
# NaN    20427       NaN           NaN         NaN        NaN       NaN
# NaN    21138       NaN           NaN         NaN        NaN       NaN
# NaN    23011       NaN           NaN         NaN        NaN       NaN
# NaN    26070       NaN           NaN         NaN        NaN       NaN
#
#      NO_SANIT     OVSAE   NO_DREN  NO_ELECT    NO_LAVA   No_REFRI       IRS
# 0.0  0.434323  0.539714  0.405613  0.185406  13.135097   4.976815 -1.345557
# 1.0  4.890338  1.171607  4.973795  0.997579  21.077503  13.729702 -0.873237
# 2.0  0.751248  0.947424  0.783724  0.612309  14.364769   6.628280 -0.954940
# 3.0  2.530502  0.671326  1.624260  0.697120  21.213440  11.657586 -1.039090
# 4.0  0.840948  0.911164  0.748003  0.439924  14.073904   6.988933 -1.182509
# ..        ...       ...       ...       ...        ...        ...       ...
# NaN       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# NaN       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# NaN       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# NaN       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# NaN       NaN       NaN       NaN       NaN        NaN        NaN       NaN
#
# [2469 rows x 13 columns]

# %%
#Check if we have NaN or empty cells

#for key in df_social_2015_2020[["OVSEE_S2015"]]:
#  if (df_social_2015_2020['OVSEE_S2015'].isnull() | df_social_2015_2020['OVSEE_S2015'] == '')

#df_social_2015_2020.loc[(df_social_2015_2020['OVSEE_S2015'].isnull() | df_social_2015_2020['OVSEE_S2015'] == ''), 'OVSEE_mean_15_19'] = df_social_2015_2020['OVSEE_S2020'] / 5 * 4

# %%
#df_social_mean_2015_2019.loc[df_social_mean_2015_2019.isnull()]
#df_social_mean_2015_2019.loc[df_social_mean_2015_2019['Mun_Code'] == "02006"].isnull()
#df_social_mean_2015_2019.loc[(df_social_mean_2015_2019['OVSEE'].isnull() | df_social_2015_2020['OVSEE'] == '')]
#print(df_social_mean_2015_2019.loc[(df_social_mean_2015_2019['Mun_Code'] == '02006')])

# %%
#Export to excel

df_social_mean_2015_2019.to_excel('data/df_social_mean_2015_2019_JR.xlsx', index = False)

# %%
#Check the variables distribution - histogram

#df_social_mean_2015_2019.iloc[:,2:4].hist(bins = 5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff122cb3a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff122c6ac50>]],
#       dtype=object)
